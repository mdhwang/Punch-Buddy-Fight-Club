# %%
import pandas as pd
import matplotlib as plt
import seaborn as sb

# %%
LR = pd.read_csv("data/test/LR/LRA.csv")
LS = pd.read_csv("data/test/LS/LSA.csv")
RR = pd.read_csv("data/test/RR/RRA.csv")
RS = pd.read_csv("data/test/RS/RSA.csv")
OGR = pd.read_csv("data/test/OGR/OGR.csv")
OGL = pd.read_csv("data/test/OGL/OGL.csv")

# %%
LS.head()
# Out:
#       epoch (ms)            time (-07:00)  elapsed (s)  X-Axis (g)  \
# 0  1586553802461  2020-04-10T14:23:22.461        0.000      -0.357
# 1  1586553802500  2020-04-10T14:23:22.500        0.039      -0.367
# 2  1586553802541  2020-04-10T14:23:22.541        0.080      -0.357
# 3  1586553802581  2020-04-10T14:23:22.581        0.120      -0.359
# 4  1586553802622  2020-04-10T14:23:22.622        0.161      -0.371
#
#    Y-Axis (g)  Z-Axis (g)
# 0      -0.518       0.850
# 1      -0.539       0.857
# 2      -0.538       0.850
# 3      -0.535       0.852
# 4      -0.522       0.862

# %%
x = LS['elapsed (s)']
y = LS['Y-Axis (g)']
sb.lineplot(x,y)

# %%
OGL.head()
# Out:
#       epoch (ms)            time (-08:00)  elapsed (s)  X-Axis (g)  \
# 0  1572983998188  2019-11-05T11:59:58.188        0.000      -0.355
# 1  1572983998229  2019-11-05T11:59:58.229        0.041      -0.601
# 2  1572983998268  2019-11-05T11:59:58.268        0.080      -1.039
# 3  1572983998309  2019-11-05T11:59:58.309        0.121      -0.841
# 4  1572983998349  2019-11-05T11:59:58.349        0.161       0.036
#
#    Y-Axis (g)  Z-Axis (g)
# 0      -0.938      -1.061
# 1      -2.195      -0.970
# 2      -2.050      -1.209
# 3      -1.246      -0.505
# 4       0.617       0.492

# %%
x1 = OGL['elapsed (s)']
y1 = OGL['X-Axis (g)']
sb.lineplot(x1,y1)

# %%
x2 = LR['elapsed (s)']
y2 = LR['X-Axis (g)']
sb.lineplot(x2,y2)

# %%
x3 = OGR['elapsed (s)']
y3 = OGR['X-Axis (g)']
sb.lineplot(x3,y3)

# %%
x4 = RS['elapsed (s)']
y4 = RS['Y-Axis (g)']
sb.lineplot(x4,y4)

# %%
x5 = RR3['elapsed (s)']
y5 = RR3['X-Axis (g)']
sb.lineplot(x5,y5)

# %%
RR2 = RR[RR['elapsed (s)'] > 0]

# %%
RR3 = RR2[RR2['elapsed (s)'] < 5]
