# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df_jab = pd.read_csv('data/raw/Left Jab/Left Jab 200 Matt Combo RC_2019-11-09T14-22-13.345/Left Jab 200 Matt Combo RC_Accelerometer_2019-11-09T14-22-13.345.csv')

# %%
df_jab.head(10)
# Out:
#       epoch (ms)            time (-08:00)  elapsed (s)  X-Axis (g)  \
# 0  1573338133424  2019-11-09T14:22:13.424        0.000      -0.130
# 1  1573338133465  2019-11-09T14:22:13.465        0.041      -0.130
# 2  1573338133505  2019-11-09T14:22:13.505        0.081      -0.131
# 3  1573338133546  2019-11-09T14:22:13.546        0.122      -0.130
# 4  1573338133586  2019-11-09T14:22:13.586        0.162      -0.130
# 5  1573338133625  2019-11-09T14:22:13.625        0.201      -0.130
# 6  1573338133666  2019-11-09T14:22:13.666        0.242      -0.131
# 7  1573338133706  2019-11-09T14:22:13.706        0.282      -0.131
# 8  1573338133747  2019-11-09T14:22:13.747        0.323      -0.131
# 9  1573338133786  2019-11-09T14:22:13.786        0.362      -0.130
#
#    Y-Axis (g)  Z-Axis (g)
# 0      -0.059       1.028
# 1      -0.060       1.037
# 2      -0.060       1.037
# 3      -0.060       1.035
# 4      -0.061       1.035
# 5      -0.060       1.035
# 6      -0.061       1.035
# ...

# %%
plt.figure(figsize=(16, 6))
sb.lineplot(df_jab["elapsed (s)"],df_jab["X-Axis (g)"])

# %%
plt.figure(figsize=(16, 6))
sb.lineplot(df_jab["elapsed (s)"],df_jab["y-axis (g)"])

# %%
plt.figure(figsize=(16, 6))
sb.lineplot(df_jab["elapsed (s)"],df_jab["z-axis (g)"])

# %%
df_gyro = pd.read_csv('data/test/TRIAL2-10JAB-GYRO-25hz.csv')

# %%
df_gyro.head(10)
# Out:
#        epoc (ms)        timestamp (-0800)  elapsed (s)  x-axis (deg/s)  \
# 0  1572895687808  2019-11-04T11.28.07.808        0.000           1.402
# 1  1572895687847  2019-11-04T11.28.07.847        0.039           1.707
# 2  1572895687887  2019-11-04T11.28.07.887        0.079           0.976
# 3  1572895687927  2019-11-04T11.28.07.927        0.119          -0.183
# 4  1572895687966  2019-11-04T11.28.07.966        0.158          -0.793
# 5  1572895688006  2019-11-04T11.28.08.006        0.198          -4.390
# 6  1572895688047  2019-11-04T11.28.08.047        0.239          -4.085
# 7  1572895688086  2019-11-04T11.28.08.086        0.278          -4.268
# 8  1572895688126  2019-11-04T11.28.08.126        0.318          -6.463
# 9  1572895688165  2019-11-04T11.28.08.165        0.357          -7.622
#
#    y-axis (deg/s)  z-axis (deg/s)
# 0          -1.159          10.427
# 1          -1.585          10.976
# 2          -1.220          12.073
# 3           0.488          11.220
# ...

# %%
plt.figure(figsize=(16, 6))
sb.lineplot(df_gyro["elapsed (s)"],df_gyro["x-axis (deg/s)"])

# %%
plt.figure(figsize=(16, 6))
sb.lineplot(df_gyro["elapsed (s)"],df_gyro["y-axis (deg/s)"])

# %%
plt.figure(figsize=(16, 6))
sb.lineplot(df_gyro["elapsed (s)"],df_gyro["z-axis (deg/s)"])

# %%
df_gyro_accel = pd.read_csv('data/test/TRIAL2-10JAB-ACCEL-12.5HZ.csv')

# %%
df_gyro_accel.head()
# Out:
#        epoc (ms)        timestamp (-0800)  elapsed (s)  x-axis (g)  \
# 0  1572895688086  2019-11-04T11.28.08.086        0.000       0.105
# 1  1572895688165  2019-11-04T11.28.08.165        0.079       0.112
# 2  1572895688244  2019-11-04T11.28.08.244        0.158       0.113
# 3  1572895688325  2019-11-04T11.28.08.325        0.239       0.102
# 4  1572895688404  2019-11-04T11.28.08.404        0.318       0.093
#
#    y-axis (g)  z-axis (g)
# 0       0.938       0.519
# 1       0.907       0.519
# 2       0.866       0.500
# 3       0.841       0.504
# 4       0.844       0.520

# %%
df_gyro.head()
# Out:
#        epoc (ms)        timestamp (-0800)  elapsed (s)  x-axis (deg/s)  \
# 0  1572895687808  2019-11-04T11.28.07.808        0.000           1.402
# 1  1572895687847  2019-11-04T11.28.07.847        0.039           1.707
# 2  1572895687887  2019-11-04T11.28.07.887        0.079           0.976
# 3  1572895687927  2019-11-04T11.28.07.927        0.119          -0.183
# 4  1572895687966  2019-11-04T11.28.07.966        0.158          -0.793
#
#    y-axis (deg/s)  z-axis (deg/s)
# 0          -1.159          10.427
# 1          -1.585          10.976
# 2          -1.220          12.073
# 3           0.488          11.220
# 4           0.732           8.780
